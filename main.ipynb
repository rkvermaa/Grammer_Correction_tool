# %%
import openai
import os
from dotenv import load_dotenv
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.chat_models import ChatOpenAI

# Load environment variables from .env file
load_dotenv()

# Set your OpenAI API key from the environment variable
openai.api_key = os.getenv('OPENAI_API_KEY')

# Read the system prompt from the file
with open('system_prompt.txt', 'r') as file:
    SYSTEM_PROMPT = file.read()

# Define the prompt template
PROMPT_TEMPLATE = """
System: {system}
Input Paragraph: "{input_paragraph}"
"""

# Create a PromptTemplate object
prompt = PromptTemplate(
    input_variables=["system", "input_paragraph"],
    template=PROMPT_TEMPLATE
)

# Create the ChatOpenAI object
llm = ChatOpenAI(temperature=0.7, model_name="gpt-3.5-turbo")  # or use "gpt-3.5-turbo"

# Create the LLM chain
chain = LLMChain(prompt=prompt, llm=llm)

# Define the input paragraph
input_paragraph = """
step ladder approach gradualy escalate diet therapy. This aproach has been creted keepiing sustainability in mind with simpler and traditional diets at start and increasingly restrictive diets at subsequent escalations. Diet ladder is being successsfully used at oour practice for the last two years with good patient adherence and satisfaction. Numerous meta-analyses have tried compare diet and ascertain the best diet, but all diets seem to work almost equally in the long term in unselected populations (Fogelholm, Anderssen, Gunnarsdottir, Lahti-Koski, 2012). Therefore, we believe, each individual would respond positively to one of the dietary approaches and the diet ladder lays down a practical framework to find that approach.
"""

# Generate the correction
result = chain.run({
    "system": SYSTEM_PROMPT,
    "input_paragraph": input_paragraph
})

# Print the result
print(result)
# Out:
# c:\Users\rkver\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# c:\Users\rkver\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# {
#     "status": true,
#     "message": "Success",
#     "input": "step ladder approach gradualy escalate diet therapy. This aproach has been creted keepiing sustainability in mind with simpler and traditional diets at start and increasingly restrictive diets at subsequent escalations. Diet ladder is being successsfully used at oour practice for the last two years with good patient adherence and satisfaction. Numerous meta-analyses have tried compare diet and ascertain the best diet, but all diets seem to work almost equally in the long term in unselected populations (Fogelholm, Anderssen, Gunnarsdottir, Lahti-Koski, 2012). Therefore, we believe, each individual would respond positively to one of the dietary approaches and the diet ladder lays down a practical framework to find that approach.",
#     "response": [
#         {
#             "sentence": "step ladder approach gradualy escalate diet therapy.",
#             "start_index": 0,
#             "end_index": 56,
#             "sentence_result": [
#                 {
#                     "start_index": 40,
#                     "end_index": 48,
#                     "covered_text": "gradualy",
#                     "output": [
#                         {
#                             "revised_text": "gradually",
#                             "comment": "Correct the spelling of 'gradualy' to 'gradually'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "sentence": "This aproach has been creted keepiing sustainability in mind with simpler and traditional diets at start and increasingly restrictive diets at subsequent escalations.",
#             "start_index": 57,
#             "end_index": 161,
#             "sentence_result": [
#                 {
#                     "start_index": 61,
#                     "end_index": 67,
#                     "covered_text": "aproach",
#                     "output": [
#                         {
#                             "revised_text": "approach",
#                             "comment": "Correct the spelling of 'aproach' to 'approach'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 },
#                 {
#                     "start_index": 79,
#                     "end_index": 84,
#                     "covered_text": "creted",
#                     "output": [
#                         {
#                             "revised_text": "created",
#                             "comment": "Correct the spelling of 'creted' to 'created'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 },
#                 {
#                     "start_index": 94,
#                     "end_index": 101,
#                     "covered_text": "keepiing",
#                     "output": [
#                         {
#                             "revised_text": "keeping",
#                             "comment": "Correct the spelling of 'keepiing' to 'keeping'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "sentence": "Diet ladder is being successsfully used at oour practice for the last two years with good patient adherence and satisfaction.",
#             "start_index": 162,
#             "end_index": 255,
#             "sentence_result": [
#                 {
#                     "start_index": 19,
#                     "end_index": 30,
#                     "covered_text": "successsfully",
#                     "output": [
#                         {
#                             "revised_text": "successfully",
#                             "comment": "Correct the spelling of 'successsfully' to 'successfully'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 },
#                 {
#                     "start_index": 50,
#                     "end_index": 53,
#                     "covered_text": "oour",
#                     "output": [
#                         {
#                             "revised_text": "our",
#                             "comment": "Correct the spelling of 'oour' to 'our'.",
#                             "type": 3,
#                             "cta_present": false,
#                             "error_id": "3a4b2f11-5e43-4a39-9b2a-8a6b566d3cee",
#                             "error_category": "Spelling"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "sentence": "Numerous meta-analyses have tried compare diet and ascertain the best diet, but all diets seem to work almost equally in the long term in unselected populations (Fogelholm, Anderssen, Gunnarsdottir, Lahti-Koski, 2012).",
#             "start_index": 256,
#             "end_index": 361,
#             "sentence_result": [
#                 {
#                     "start_index": 19,
#                     "end_index": 26,
#                     "covered_text": "compare",
#                     "output": [
#                         {
#                             "revised_text": "comparing",
#                             "comment": "Consider changing 'compare' to 'comparing' for better grammar.",
#                             "type": 1,
#                             "cta_present": true,
#                             "error_id": "7a2d5d67-6b9a-4c3c-9a2b-19e3f04f7e5d",
#                             "error_category": "Grammar"
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     "language": "US",
#     "style_guide": "ACS"
# }

# %%
import json
json.loads(result)
# Out:
# {'response': [{'sentence': 'Step ladder approach gradually escalates diet therapy. This approach has been created keeping sustainability in mind with simpler and traditional diets at the start and increasingly restrictive diets at subsequent escalations. Diet ladder is being successfully used at our practice for the last two years with good patient adherence and satisfaction. Numerous meta-analyses have tried to compare diet and ascertain the best diet, but all diets seem to work almost equally in the long term in unselected populations (Fogelholm, Anderssen, Gunnarsdottir, Lahti-Koski, 2012). Therefore, we believe each individual would respond positively to one of the dietary approaches and the diet ladder lays down a practical framework to find that approach.',
#    'start_index': 1,
#    'end_index': 772,
#    'sentence_result': [{'start_index': 0,
#      'end_index': 3,
#      'covered_text': 'step',
#      'output': [{'revised_text': 'Step',
#        'comment': 'Corrected the capitalization.'}]},
#     {'start_index': 38,
#      'end_index': 45,
#      'covered_text': 'gradualy',
#      'output': [{'revised_text': 'gradually',
#        'comment': "Corrected spelling from 'gradualy' to 'gradually'."}]},
#     {'start_index': 58,
#      'end_index': 64,
#      'covered_text': 'aproach',
#      'output': [{'revised_text': 'approach',
#        'comment': "Corrected spelling from 'aproach' to 'approach'."}]},
#     {'start_index': 102,
#      'end_index': 110,
#      'covered_text': 'creted',
#      'output': [{'revised_text': 'created',
#        'comment': "Corrected spelling from 'creted' to 'created'."}]},
#     {'start_index': 111,
#      'end_index': 119,
#      'covered_text': 'keepiing',
#      'output': [{'revised_text': 'keeping',
#        'comment': "Corrected spelling from 'keepiing' to 'keeping'."}]},
#     {'start_index': 192,
#      'end_index': 195,
#      'covered_text': 'oour',
#      'output': [{'revised_text': 'our',
#        'comment': "Corrected spelling from 'oour' to 'our'."}]},
#     {'start_index': 225,
#      'end_index': 233,
#      'covered_text': 'successsfully',
#      'output': [{'revised_text': 'successfully',
#        'comment': "Corrected spelling from 'successsfully' to 'successfully'."}]}]}]}

# %%
os.getenv('OPENAI_API_KEY')
# Out:
# 'sk-proj-5EQvBE1T4JfjTiwLX2kbT3BlbkFJ0btjjNq4FdWJ0RHuHxnP'

# %%
from dotenv import load_dotenv
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.chat_models import ChatOpenAI

# Load environment variables from .env file
load_dotenv()

# Set your OpenAI API key from the environment variable
openai.api_key = os.getenv('OPENAI_API_KEY')
